# %% [markdown]
# # Lab Segmentation 2

# %%
from commonfunctions import *
from skimage import io
from skimage.filters import threshold_otsu
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_threshold(orig_image):
    MIN = np.min(orig_image)
    MAX = np.max(orig_image)
    print("max_min={}".format(MAX-MIN))
    if(MAX - MIN <= 1):
        orig_image = 255 * orig_image;
        print("transformed")
    orig_image = orig_image.astype(np.uint8)
    image_size = orig_image.shape[0]*orig_image.shape[1]
    pixel_counts = np.array([len(orig_image[orig_image == p]) for p in range(256)])
    pixel_counts = pixel_counts / image_size
    # 3
    thresh = np.round(np.sum([p*pixel_counts[p] for p in range(256)]))
    thresh = int(thresh)
    # 4.
    #get lower weighted average 
    old_threshold = -1
    while thresh != old_threshold :
        mu1 = np.round(np.sum([p * pixel_counts[p] for p in range(0,thresh)]))
        # get upper weighted average
        mu2 = np.round(np.sum([p * pixel_counts[p] for p in range(thresh,256)]))
        old_threshold = thresh
        thresh = int((mu1+mu2)/2)
    return thresh

# %%
paths = ['cufe.png','cameraman.png', 'book1.png']
for path in paths:
    orig_image = io.imread(path,as_gray=True)
    thresh = get_threshold(orig_image)
    print(thresh)
    print(orig_image)
        MIN = np.min(orig_image)
    MAX = np.max(orig_image)
    print("max_min={}".format(MAX-MIN))
    if(MAX - MIN <= 1):
        orig_image = 255 * orig_image;
    # 5. update
    binary_image = orig_image.copy()
    binary_image[binary_image <= thresh]=0
    binary_image[binary_image > thresh]=255
    show_images([orig_image,binary_image], ["original","binary image"])
# Out:
# max_min=0.9686274509803922
# transformed
# 82
# [[0.9232949  0.93113804 0.93505961 ... 0.58895255 0.58728588 0.59120745]
#  [0.91937333 0.9232949  0.92721647 ... 0.59287412 0.59120745 0.59120745]
#  [0.91545176 0.91545176 0.91937333 ... 0.59287412 0.59679569 0.59679569]
#  ...
#  [0.34139961 0.34139961 0.33355647 ... 0.29463843 0.29856    0.29463843]
#  [0.30748941 0.30888824 0.31673137 ... 0.38875608 0.38091294 0.38483451]
#  [0.29572471 0.30356784 0.31533255 ... 0.6358149  0.60836392 0.60836392]]
# max_min=246
# 59
# [[156 159 158 ... 151 152 152]
#  [160 154 157 ... 154 155 153]
#  [156 159 158 ... 151 152 152]
#  ...
#  [114 132 123 ... 135 137 114]
#  [121 126 130 ... 133 130 113]
#  [121 126 130 ... 133 130 113]]
# max_min=0.5457458823529411
# transformed
# 78
# [[0.61425569 0.62602039 0.62209882 ... 0.60428471 0.60036314 0.59644157]
#  [0.61033412 0.61817725 0.61425569 ... 0.61212784 0.61212784 0.61212784]
#  [0.61033412 0.61817725 0.61817725 ... 0.61212784 0.61212784 0.61604941]
#  ...
#  [0.57896157 0.57896157 0.57504    ... 0.46825098 0.47609412 0.48001569]
#  [0.57504    0.57504    0.57896157 ... 0.46040784 0.47217255 0.48001569]
#  [0.57504    0.57504    0.57896157 ... 0.46040784 0.47217255 0.48001569]]
